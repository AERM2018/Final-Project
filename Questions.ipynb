# %%
Questions = {
    1:{
        "q":"Hola soy la pregunta 1",
        "a":"respuesta1",
        "b":"respuesta2",
        "c":"respuesta3",
        "d":"respuesta4",
        "correct":"a"
    },
    2:{
        "q":"Hola soy la pregunta 2",
        "ans1":"respuesta1",
        "ans2":"respuesta2",
        "ans3":"respuesta3",
        "ans4":"respuesta4",
        "correct":"respuesta2"
    },
    3:{
        "q":"Hola soy la segunda pregunta 3",
        "ans1":"respuesta1",
        "ans2":"respuesta2",
        "ans3":"respuesta3",
        "ans4":"respuesta4",
        "correct":"respuesta2"
    },
    4:{
        "q":"Hola soy la segunda pregunta 4",
        "ans1":"respuesta1",
        "ans2":"respuesta2",
        "ans3":"respuesta3",
        "ans4":"respuesta4",
        "correct":"respuesta2"
    },
    5:{
        "q":"Hola soy la segunda pregunta 5",
        "ans1":"respuesta1",
        "ans2":"respuesta2",
        "ans3":"respuesta3",
        "ans4":"respuesta4",
        "correct":"respuesta2"
    },
    6:{
        "q":"Hola soy la segunda pregunta 6",
        "ans1":"respuesta1",
        "ans2":"respuesta2",
        "ans3":"respuesta3",
        "ans4":"respuesta4",
        "correct":"respuesta2"
    },
    7:{
        "q":"Hola soy la segunda pregunta 7",
        "ans1":"respuesta1",
        "ans2":"respuesta2",
        "ans3":"respuesta3",
        "ans4":"respuesta4",
        "correct":"respuesta2"
    },
    8:{
        "q":"Hola soy la segunda pregunta 8",
        "ans1":"respuesta1",
        "ans2":"respuesta2",
        "ans3":"respuesta3",
        "ans4":"respuesta4",
        "correct":"respuesta2"
    },
    9:{
        "q":"Hola soy la segunda pregunta 9",
        "ans1":"respuesta1",
        "ans2":"respuesta2",
        "ans3":"respuesta3",
        "ans4":"respuesta4",
        "correct":"respuesta2"
    },
    10:{
        "q":"Hola soy la segunda pregunta 10",
        "ans1":"respuesta1",
        "ans2":"respuesta2",
        "ans3":"respuesta3",
        "ans4":"respuesta4",
        "correct":"respuesta2"
    },
    11:{
        "q":"Hola soy la segunda pregunta 11",
        "ans1":"respuesta1",
        "ans2":"respuesta2",
        "ans3":"respuesta3",
        "ans4":"respuesta4",
        "correct":"respuesta2"
    }
}


# for i in Questions.keys():
